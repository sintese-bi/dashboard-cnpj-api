# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\saulo\OneDrive\Desktop\GIT\dashboard-cnpj-api\dados_exportados.xlsx')
df['cnae'].to_list()[0]
# Out:
# 'Atividades de intermediação e agenciamento de serviços e negócios em geral, exceto imobiliários'

# %%
import base64

# Caminho para a imagem JPG
caminho_imagem = r'C:\Users\saulo\OneDrive\Desktop\GIT\dashboard-cnpj-api\logo.jpg'

# Abrir a imagem em modo de leitura binária
with open(caminho_imagem, "rb") as imagem_file:
    # Converter a imagem para base64
    imagem_base64 = base64.b64encode(imagem_file.read()).decode('utf-8')

# Exibir a string em base64
print(imagem_base64)
# Out:
# ...

# %%
imagem_base64
# Out:
# '...'
